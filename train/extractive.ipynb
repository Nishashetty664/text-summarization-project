# %%
import pandas as pd  # Import pandas for data handling
import nltk  # Import NLTK for natural language processing tasks
from nltk.tokenize import sent_tokenize, word_tokenize  # Import tokenization functions
from nltk.corpus import stopwords  # Import stopwords from NLTK corpus
from sklearn.metrics.pairwise import cosine_similarity  # Import cosine similarity for similarity calculation
import numpy as np  # Import NumPy for numerical operations
import networkx as nx  # Import NetworkX for graph-based algorithms
from sklearn.metrics import precision_score, recall_score, f1_score  # Import metrics for evaluation
from tqdm import tqdm  # Import tqdm for progress bar visualization

# Download NLTK data files (if not already downloaded)
nltk.download('punkt')  # Download NLTK's punkt tokenizer
nltk.download('stopwords')  # Download NLTK's stopwords
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function to read the dataset
def read_dataset(file_path):
    # Read CSV file into a DataFrame
    return pd.read_csv(file_path)  # Returns a DataFrame containing the dataset

# Function to preprocess text into sentences
def preprocess_text(text):
    # Tokenize text into sentences
    sentences = sent_tokenize(text)
    return sentences  # Returns a list of sentences

# %%
# Function to calculate similarity between two sentences using cosine similarity
def sentence_similarity(sent1, sent2):
    stop_words = set(stopwords.words('english'))  # Get English stopwords
    # Tokenize and remove stopwords
    sent1 = [w.lower() for w in word_tokenize(sent1) if w.lower() not in stop_words]
    sent2 = [w.lower() for w in word_tokenize(sent2) if w.lower() not in stop_words]

    all_words = list(set(sent1 + sent2))  # Get all unique words from both sentences

    # Initialize vectors for word counts
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)

    # Count word occurrences in each sentence
    for w in sent1:
        vector1[all_words.index(w)] += 1
    for w in sent2:
        vector2[all_words.index(w)] += 1

    # Compute cosine similarity between the vectors
    similarity = cosine_similarity([vector1], [vector2])[0][0]
    return similarity  # Returns a float representing the cosine similarity

# %%
# Example of building a similarity matrix of sentences based on a threshold
def build_similarity_matrix(sentences, threshold=0.2):
    similarity_matrix = np.zeros((len(sentences), len(sentences)))

    # Calculate similarity between all pairs of sentences
    for i in range(len(sentences)):
        for j in range(len(sentences)):
            if i != j:
                similarity = sentence_similarity(sentences[i], sentences[j])
                if similarity > threshold:
                    similarity_matrix[i][j] = similarity

    return similarity_matrix  # Returns a 2D NumPy array (similarity matrix)

# Function to generate summary using TextRank algorithm
def textrank_summarize(text, top_n=5):
    sentences = preprocess_text(text)  # Preprocess text into sentences
    similarity_matrix = build_similarity_matrix(sentences)  # Build similarity matrix based on sentences

    # Convert similarity matrix to a graph
    similarity_graph = nx.from_numpy_array(similarity_matrix)
    scores = nx.pagerank(similarity_graph)  # Compute PageRank scores for ranking sentences

    # Rank sentences based on PageRank scores
    ranked_sentences = sorted(((scores[i], s) for i, s in enumerate(sentences)), reverse=True)

    # Ensure that top_n does not exceed available sentences
    top_n = min(top_n, len(ranked_sentences))

    # Select top N sentences for summary
    summary = ' '.join([ranked_sentences[i][1] for i in range(top_n)])
    return summary  # Returns a string (generated summary)

# %%
# Function to evaluate the generated summary against a reference summary
def evaluate_summary(generated_summary, reference_summary):
    generated_tokens = set(word_tokenize(generated_summary))  # Tokenize generated summary
    reference_tokens = set(word_tokenize(reference_summary))  # Tokenize reference summary

    common_tokens = generated_tokens.intersection(reference_tokens)  # Find common tokens

    # Calculate precision, recall, and F1 score based on token overlap
    if len(generated_tokens) == 0 or len(reference_tokens) == 0:
        return 0, 0, 0

    precision = len(common_tokens) / len(generated_tokens)
    recall = len(common_tokens) / len(reference_tokens)

    if precision + recall == 0:
        f1 = 0
    else:
        f1 = 2 * (precision * recall) / (precision + recall)

    return precision, recall, f1  # Returns three floats (precision, recall, F1 score)

# Main function to summarize texts in the dataset and evaluate the summaries
def main():
    file_path = '/content/drive/My Drive/train_extract.csv'  # Path to your dataset CSV file
    df = read_dataset(file_path)  # Read dataset into DataFrame

    summaries = []  # List to store generated summaries
    precisions = []  # List to store precision scores
    recalls = []  # List to store recall scores
    f1s = []  # List to store F1 scores

    # Iterate through each row in the dataset
    for i, row in tqdm(df.iterrows(), total=len(df), desc="Summarizing"):
        summary = textrank_summarize(row['article'], top_n=5)  # Generate summary for each article
        summaries.append(summary)  # Append generated summary to list

        # Evaluate generated summary against reference summary (assumed in 'highlight' column)
        precision, recall, f1 = evaluate_summary(summary, row['highlight'])
        precisions.append(precision)  # Append precision score
        recalls.append(recall)  # Append recall score
        f1s.append(f1)  # Append F1 score

    # Add generated summaries to the DataFrame
    df['summary'] = summaries

    # Save DataFrame with summaries to a new CSV file
    df.to_csv('/content/drive/My Drive/summarized_train_new1.csv', index=False)
    print("Summarization complete. Summarized data saved to 'summarized_train_new1.csv'.")

    # Calculate average precision, recall, and F1 score
    avg_precision = sum(precisions) / len(precisions)
    avg_recall = sum(recalls) / len(recalls)
    avg_f1 = sum(f1s) / len(f1s)

    # Print average evaluation scores
    print(f"Average Precision: {avg_precision}")
    print(f"Average Recall: {avg_recall}")
    print(f"Average F1 Score: {avg_f1}")

# Execute main function if script is run directly
if __name__ == "__main__":
    main()
# Out:
# Summarizing: 100%|██████████| 7200/7200 [00:25<00:00, 282.78it/s]
# Summarization complete. Summarized data saved to 'summarized_train_new1.csv'.
# Average Precision: 0.11915116275924399
# Average Recall: 0.8122832639127101
# Average F1 Score: 0.20232146562006512

# %%
import pandas as pd

# Function to display summarized data
def display_summarized_data(file_path, num_records=2):
    # Read the summarized CSV file into a DataFrame
    df = pd.read_csv(file_path)

    # Display the first num_records records
    print(f"Displaying first {num_records} records from {file_path}:")
    for i in range(num_records):
        print(f"\nRecord {i+1}:")
        print(f"Article:\n{df.loc[i, 'article']}")
        print(f"\nGenerated Summary:\n{df.loc[i, 'summary']}")
        print(f"\nReference Summary:\n{df.loc[i, 'highlight']}")
        print("\n---")

# Example usage:
file_path = '/content/drive/My Drive/summarized_train_new1.csv'  # Replace with your actual file path
display_summarized_data(file_path)
# Out:
# Displaying first 2 records from /content/drive/My Drive/summarized_train_new1.csv:
#
# Record 1:
# Article:
# kept two young women locked sex slaves basement ariel castro looking wife new book cleveland kidnapper revealed 39yearold woman named lillian roldan came forward author john glatt say dated castro 2000 2003 threeyear period castro kidnapped imprisoned michelle knight amanda berry ohio home roldan describes castro glatts book lost girls nothing short gentleman completely normal bedroom even romantic scroll video blinded love lillian roldan left says dated cleveland kidnapper ariel castro right 2000 2003 says visited house often never knew young women keeping prisoner however says keep basement padlocked found peculiar asked need lock door castro allegedly told roldan kept money stored didnt want kids steal book set published later month roldan recalls meeting 16yearsolder castro blind date set friends may 2000 allegedly invited watch play music one night love first sight nose three years castro would kidnap 21yearold michelle knight 17yearold amanda berry months breaking kidnapped third victim gina dejuses roldan pictured another man picture posted facebook seemingly normal roldan detailed romantic relationship castro new book lost girls john glatt roldan visited castro house often sometimes ran exwife grimilda figueroa castro abused figuero marriage acted kind around roldan thought beatings rumor sex life roldan says castro completely normal considerate says one point relationship castro popped question roldan declined since didnt believe marriage proposal castro remained dedicated roldan even bought ruby ring buying flashy piece jewelry castro took roldan along one music gigs yet another romantic gesture store free women amanda berry left gina dejesus center michelle knight right held captive castros home years found freedom may 2013 berrys 6yearold child helped trio escape stolen youth castro kidnapped michelle knight right 2002 21 eight months later kidnapped 17yearold amanda berry left year later captured 14yearold gina dejesus center midway performance took microphone told audience today gave girlfriend lillian ring everyone clapped lillian recalls told group wanted sing la bamba romantic charmed special night really show love castro remained normal man called boyfriend two years relationship started harboring secret home august 2002 castro kidnapped 21yearold michelle knight locked basement eight months later kidnapped another girl 17yearold amanda berry apparently distracted two young women torturing home castro abruptly cut ties roldan october year sending letter said didnt love enough stay prison catros cleveland home kept three women locked years five months roldan received unexpected breakup letter castros third victim gina dejesus went missing 14 years old time next nine years women locked inside castros home kept secret outside world three women found freedom may 2013 berrys 6yearold daughter castro helped trio escape house alert police castro arrested sentenced life prison plus 1000 years month sentencing castro committed suicide prison
#
# Generated Summary:
# kept two young women locked sex slaves basement ariel castro looking wife new book cleveland kidnapper revealed 39yearold woman named lillian roldan came forward author john glatt say dated castro 2000 2003 threeyear period castro kidnapped imprisoned michelle knight amanda berry ohio home roldan describes castro glatts book lost girls nothing short gentleman completely normal bedroom even romantic scroll video blinded love lillian roldan left says dated cleveland kidnapper ariel castro right 2000 2003 says visited house often never knew young women keeping prisoner however says keep basement padlocked found peculiar asked need lock door castro allegedly told roldan kept money stored didnt want kids steal book set published later month roldan recalls meeting 16yearsolder castro blind date set friends may 2000 allegedly invited watch play music one night love first sight nose three years castro would kidnap 21yearold michelle knight 17yearold amanda berry months breaking kidnapped third victim gina dejuses roldan pictured another man picture posted facebook seemingly normal roldan detailed romantic relationship castro new book lost girls john glatt roldan visited castro house often sometimes ran exwife grimilda figueroa castro abused figuero marriage acted kind around roldan thought beatings rumor sex life roldan says castro completely normal considerate says one point relationship castro popped question roldan declined since didnt believe marriage proposal castro remained dedicated roldan even bought ruby ring buying flashy piece jewelry castro took roldan along one music gigs yet another romantic gesture store free women amanda berry left gina dejesus center michelle knight right held captive castros home years found freedom may 2013 berrys 6yearold child helped trio escape stolen youth castro kidnapped michelle knight right 2002 21 eight months later kidnapped 17yearold amanda berry left year later captured 14yearold gina dejesus center midway performance took microphone told audience today gave girlfriend lillian ring everyone clapped lillian recalls told group wanted sing la bamba romantic charmed special night really show love castro remained normal man called boyfriend two years relationship started harboring secret home august 2002 castro kidnapped 21yearold michelle knight locked basement eight months later kidnapped another girl 17yearold amanda berry apparently distracted two young women torturing home castro abruptly cut ties roldan october year sending letter said didnt love enough stay prison catros cleveland home kept three women locked years five months roldan received unexpected breakup letter castros third victim gina dejesus went missing 14 years old time next nine years women locked inside castros home kept secret outside world three women found freedom may 2013 berrys 6yearold daughter castro helped trio escape house alert police castro arrested sentenced life prison plus 1000 years month sentencing castro committed suicide prison
#
# Reference Summary:
# lillian roldan says dated ariel castro 2000 2003 according new book cleveland house horrors john glatt roldan says met castro blind date threeyear relationship nothing gentleman two years relationship castro kidnapped first two victims michelle knight amanda berry locked basement roldan says never knew castro hiding women keep padlock basement door castro broke roldan letter october 2003 months later went kidnap third victim gina dejesus three women kept captive house another nine years made dramatic escape may 2013
#
# ---
#
# Record 2:
# Article:
# afghanistans first female pilot serve air force since fall taliban honoured us secretary states international women courage award niloofar rahmani 23 defied death threats terror group even members extended family become first female fixedwing air force aviator afghanistans history first female pilot afghan military since fall taliban 2001 captain rahmani nine inspirational women across world awarded us secretary states international women courage award 2015 ceremony last week scroll video captain niloofar rahmani 23 pictured first female female pilot afghan military since fall taliban 2001 last week nine women across world awarded us secretary states international women courage award captain rahmani first female fixedwing air force aviator afghanistans history received death threats taliban 18 heard news announcement saying afghan air force wanted recruit pilots captain rahmani said ever since little girl dreamed becoming pilot spent nearly year studying english order able attend flight school enlisted afghan air force officer training program 2010 july 2012 graduated second lieutenant flew first solo flight cessna 182 decided wanted fly even larger aircraft attended advanced flight school soon flying c208 military cargo aircraft women traditionally banned transporting dead wounded soldiers captain rahmani defied orders discovered injured soldiers landed mission flew injured men hospital reported actions superiors chose impose sanctions achievements publicised captain rahmanis family received threats family members taliban disapproved ambition career choices 18 heard news announcement saying afghan air force wanted recruit pilots immediately applied enlisted afghan air force officer training program 2010 july 2012 graduated second lieutenant family forced move several times safety reasons captain rahmani resolute says eventually aims become flight instructor inspire women spite talibans threats says remains determined continue career afghan air force work frequently security situation permits also deeply committed encouraging young women join cadre female aaf pilots cant see woman human believe captain rahmani told wtkr easy finishing flight school hard someone accept risk women dream award ceremony last week first lady michelle obama honored rahmanis bravery commitment empowerment women girls afghanistan established 2007 annual secretary states international women courage award honors women around globe exemplified exceptional courage leadership advocating human rights womens equality social progress often great personal risk family received death threats captain rahmani says responsibility example young girls first lady michelle obama recently honored rahmanis bravery commitment empowerment women girls afghanistan afghanistan captain niloofar rahmani afghan air force bangladesh nadia sharmeen journalist bolivia rosa julieta montano salvatierra founder director oficina juridica para la mujer burma may sabe phyu director gender equality network central african republic beatrice epaye president fondation voix du coeur guinea marie claire tchecola emergency room nurse donka hospital japan sayaka osakabe founder representative matahara net kosovo arbana xharra editorinchief zeri pakistan tabassum adnan kwendo jirga sisters council swa syria majd chourbaji external relations director women development centers
#
# Generated Summary:
# afghanistans first female pilot serve air force since fall taliban honoured us secretary states international women courage award niloofar rahmani 23 defied death threats terror group even members extended family become first female fixedwing air force aviator afghanistans history first female pilot afghan military since fall taliban 2001 captain rahmani nine inspirational women across world awarded us secretary states international women courage award 2015 ceremony last week scroll video captain niloofar rahmani 23 pictured first female female pilot afghan military since fall taliban 2001 last week nine women across world awarded us secretary states international women courage award captain rahmani first female fixedwing air force aviator afghanistans history received death threats taliban 18 heard news announcement saying afghan air force wanted recruit pilots captain rahmani said ever since little girl dreamed becoming pilot spent nearly year studying english order able attend flight school enlisted afghan air force officer training program 2010 july 2012 graduated second lieutenant flew first solo flight cessna 182 decided wanted fly even larger aircraft attended advanced flight school soon flying c208 military cargo aircraft women traditionally banned transporting dead wounded soldiers captain rahmani defied orders discovered injured soldiers landed mission flew injured men hospital reported actions superiors chose impose sanctions achievements publicised captain rahmanis family received threats family members taliban disapproved ambition career choices 18 heard news announcement saying afghan air force wanted recruit pilots immediately applied enlisted afghan air force officer training program 2010 july 2012 graduated second lieutenant family forced move several times safety reasons captain rahmani resolute says eventually aims become flight instructor inspire women spite talibans threats says remains determined continue career afghan air force work frequently security situation permits also deeply committed encouraging young women join cadre female aaf pilots cant see woman human believe captain rahmani told wtkr easy finishing flight school hard someone accept risk women dream award ceremony last week first lady michelle obama honored rahmanis bravery commitment empowerment women girls afghanistan established 2007 annual secretary states international women courage award honors women around globe exemplified exceptional courage leadership advocating human rights womens equality social progress often great personal risk family received death threats captain rahmani says responsibility example young girls first lady michelle obama recently honored rahmanis bravery commitment empowerment women girls afghanistan afghanistan captain niloofar rahmani afghan air force bangladesh nadia sharmeen journalist bolivia rosa julieta montano salvatierra founder director oficina juridica para la mujer burma may sabe phyu director gender equality network central african republic beatrice epaye president fondation voix du coeur guinea marie claire tchecola emergency room nurse donka hospital japan sayaka osakabe founder representative matahara net kosovo arbana xharra editorinchief zeri pakistan tabassum adnan kwendo jirga sisters council swa syria majd chourbaji external relations director women development centers
#
# Reference Summary:
# niloofar rahmani 23 first female pilot afghani military since fall taliban 2001 family forced move several times receiving death threats taliban captain rahmani awarded us secretary states international women courage award
#
# ---
